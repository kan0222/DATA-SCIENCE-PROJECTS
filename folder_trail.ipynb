# %% [markdown]
# <a href="https://colab.research.google.com/github/kan0222/DATA-SCIENCE-PROJECTS/blob/main/folder_trail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

allan = pd.read_csv('/content/BMW sales data (2010-2024) (1).csv')

# Count models
model_counts = allan["Transmission"].value_counts()

# Pie chart
plt.pie(
    model_counts,
    labels=model_counts.index,
    autopct='%1.1f%%',
    shadow=True,
    startangle=140
)
plt.title("BMW Sales Data (2010–2024) by Transmission")
plt.show()
